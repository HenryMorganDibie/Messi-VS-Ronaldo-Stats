# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Messi vs Ronaldo Stat.xlsx')
df.head()
# Out:
#    Messi Games  Messi Goals  Messi Assists       Year  Ronaldo Assists  \
# 0           32           18             17  2022/2023                4
# 1           34           11             14  2021/2022                3
# 2           47           38             12  2020/2021                5
# 3           44           31             25  2019/2020                5
# 4           50           51             19  2018/2019               10
#
#    Ronaldo Goals  Ronaldo Games
# 0             12             26
# 1             24             39
# 2             36             44
# 3             37             46
# 4             28             43

# %%
df.tail()
# Out:
#     Messi Games  Messi Goals  Messi Assists       Year  Ronaldo Assists  \
# 16           36           17              3  2006/2007               14
# 17           25            8              3  2005/2006                8
# 18            9            1              0  2004/2005                8
# 19            0            0              0  2003/2004                6
# 20            0            0              0  2002/2003                4
#
#     Ronaldo Goals  Ronaldo Games
# 16             23             53
# 17             12             47
# 18              9             50
# 19              6             40
# 20              5             31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Messi Games      21 non-null     int64
#  1   Messi Goals      21 non-null     int64
#  2   Messi Assists    21 non-null     int64
#  3   Year             21 non-null     object
#  4   Ronaldo Assists  21 non-null     int64
#  5   Ronaldo Goals    21 non-null     int64
#  6   Ronaldo Games    21 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.3+ KB

# %%
len(df)
# Out:
# 21

# %%
#Finding Duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Messi Games  Messi Goals  Messi Assists  Ronaldo Assists  \
# count    21.000000    21.000000      21.000000        21.000000
# mean     40.190476    33.380952      14.285714         9.666667
# std      17.926570    22.044220       8.984113         4.767949
# min       0.000000     0.000000       0.000000         3.000000
# 25%      34.000000    16.000000      11.000000         6.000000
# 50%      47.000000    38.000000      15.000000         8.000000
# 75%      52.000000    51.000000      19.000000        14.000000
# max      60.000000    73.000000      30.000000        21.000000
#
#        Ronaldo Goals  Ronaldo Games
# count      21.000000      21.000000
# mean       33.809524      45.666667
# std        18.117999       7.951939
# min         5.000000      26.000000
# 25%        23.000000      43.000000
# 50%        36.000000      47.000000
# 75%        51.000000      53.000000
# max        61.000000      55.000000

# %%
df.corr()
# Out:
#                  Messi Games  Messi Goals  Messi Assists  Ronaldo Assists  \
# Messi Games         1.000000     0.898391       0.825453         0.541302
# Messi Goals         0.898391     1.000000       0.797210         0.641101
# Messi Assists       0.825453     0.797210       1.000000         0.477405
# Ronaldo Assists     0.541302     0.641101       0.477405         1.000000
# Ronaldo Goals       0.846039     0.862115       0.793782         0.707100
# Ronaldo Games       0.451885     0.460274       0.329642         0.701140
#
#                  Ronaldo Goals  Ronaldo Games
# Messi Games           0.846039       0.451885
# Messi Goals           0.862115       0.460274
# Messi Assists         0.793782       0.329642
# Ronaldo Assists       0.707100       0.701140
# Ronaldo Goals         1.000000       0.599579
# Ronaldo Games         0.599579       1.000000

# %%
#Correlation
sns.set(style="white")

# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# C:\Users\Henry Morgan\AppData\Local\Temp\ipykernel_10416\70320809.py:8: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)
# <AxesSubplot:>

# %%
# Select the relevant columns for Messi and Ronaldo
messi_data = df[["Messi Goals", "Messi Assists", "Messi Games"]]
ronaldo_data = df[["Ronaldo Goals", "Ronaldo Assists", "Ronaldo Games"]]

# Compute the correlation matrix for Messi and Ronaldo
messi_corr = messi_data.corr()
ronaldo_corr = ronaldo_data.corr()

# Plot the correlation matrix heatmaps for Messi and Ronaldo
fig, axs = plt.subplots(ncols=2, figsize=(10, 5))
sns.heatmap(messi_corr, annot=True, cmap="coolwarm", ax=axs[0])
axs[0].set_title("Messi")
sns.heatmap(ronaldo_corr, annot=True, cmap="coolwarm", ax=axs[1])
axs[1].set_title("Ronaldo")
plt.show()

# %%
#EDA

# %%
# Summarize the data
print(df.head())
print(df.describe())

# Visualize the data
plt.hist(df["Messi Goals"], alpha=0.5, label="Messi Goals")
plt.hist(df["Ronaldo Goals"], alpha=0.5, label="Ronaldo Goals")
plt.xlabel("Goals")
plt.ylabel("Frequency")
plt.legend()
plt.show()

sns.boxplot(x="Year", y="Messi Goals", data=df)
plt.xticks(rotation=45)
plt.show()

sns.scatterplot(x="Messi Assists", y="Messi Goals", data=df)
plt.show()

# Test a hypothesis
from scipy.stats import ttest_ind

goals_2021_messi = df[df["Year"] == "2021/2022"]["Messi Goals"]
goals_2021_ronaldo = df[df["Year"] == "2021/2022"]["Ronaldo Goals"]
pvalue = ttest_ind(goals_2021_messi, goals_2021_ronaldo)[1]
if pvalue < 0.05:
    print("There is a significant difference between Messi and Ronaldo's goals in the 2021/2022 season.")
else:
    print("There is no significant difference between Messi and Ronaldo's goals in the 2021/2022 season.")

# Clean the data
df = df.dropna()
df = df[df["Messi Goals"] < 100]
df = df[df["Ronaldo Goals"] < 100]
# Out:
#    Messi Games  Messi Goals  Messi Assists       Year  Ronaldo Assists  \
# 0           32           18             17  2022/2023                4
# 1           34           11             14  2021/2022                3
# 2           47           38             12  2020/2021                5
# 3           44           31             25  2019/2020                5
# 4           50           51             19  2018/2019               10
#
#    Ronaldo Goals  Ronaldo Games
# 0             12             26
# 1             24             39
# 2             36             44
# 3             37             46
# 4             28             43
#        Messi Games  Messi Goals  Messi Assists  Ronaldo Assists  \
# count    21.000000    21.000000      21.000000        21.000000
# mean     40.190476    33.380952      14.285714         9.666667
# std      17.926570    22.044220       8.984113         4.767949
# min       0.000000     0.000000       0.000000         3.000000
# 25%      34.000000    16.000000      11.000000         6.000000
# 50%      47.000000    38.000000      15.000000         8.000000
# 75%      52.000000    51.000000      19.000000        14.000000
# max      60.000000    73.000000      30.000000        21.000000
#
#        Ronaldo Goals  Ronaldo Games
# count      21.000000      21.000000
# mean       33.809524      45.666667
# std        18.117999       7.951939
# min         5.000000      26.000000
# 25%        23.000000      43.000000
# 50%        36.000000      47.000000
# 75%        51.000000      53.000000
# max        61.000000      55.000000
# There is no significant difference between Messi and Ronaldo's goals in the 2021/2022 season.
# C:\Users\Henry Morgan\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3757: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\Users\Henry Morgan\anaconda3\lib\site-packages\numpy\core\_methods.py:256: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Feature Engineering

# %%
# Create a new variable for Messi's goals per game
df["Messi Goals Per Game"] = df["Messi Goals"] / df["Messi Games"]

# Create a new variable for Ronaldo's goals per game
df["Ronaldo Goals Per Game"] = df["Ronaldo Goals"] / df["Ronaldo Games"]

# Print the first few rows of the data to check the new variables
print(df.head())
# Out:
#    Messi Games  Messi Goals  Messi Assists       Year  Ronaldo Assists  \
# 0           32           18             17  2022/2023                4
# 1           34           11             14  2021/2022                3
# 2           47           38             12  2020/2021                5
# 3           44           31             25  2019/2020                5
# 4           50           51             19  2018/2019               10
#
#    Ronaldo Goals  Ronaldo Games  Messi Goals Per Game  Ronaldo Goals Per Game
# 0             12             26              0.562500                0.461538
# 1             24             39              0.323529                0.615385
# 2             36             44              0.808511                0.818182
# 3             37             46              0.704545                0.804348
# 4             28             43              1.020000                0.651163

# %%
# Hypothesis Testing

# %%
from scipy.stats import ttest_ind

# Create a new variable for Ronaldo's goals per game
df["Ronaldo Goals Per Game"] = df["Ronaldo Goals"] / df["Ronaldo Games"]

# Remove any rows with missing values
df.dropna(inplace=True)

# Perform a two-sample t-test to compare Messi and Ronaldo's goals per game
t_stat, p_value = ttest_ind(df["Messi Goals Per Game"], df["Ronaldo Goals Per Game"], equal_var=False)

# Print the results
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -0.22474028517867933
# p-value: 0.8234565161330686

# %%
# Modeling

# %%
# prediction of Messi's goals based on his games and assists

# %%
from sklearn.linear_model import LinearRegression

# Define the features and target variable
X = df[["Messi Games", "Messi Assists"]]
y = df["Messi Goals"]

# Fit a linear regression model to the data
model = LinearRegression()
model.fit(X, y)

# Predict Messi's goals for a new game and assist value
new_game = 30
new_assists = 10
new_data = pd.DataFrame({"Messi Games": [new_game], "Messi Assists": [new_assists]})
new_goals = model.predict(new_data)

# Print the predicted number of goals
print("Predicted goals:", new_goals[0])
# Out:
# Predicted goals: 16.25267913986719

# %%
# Scatter plot of Messi's goals versus games

# Create a scatter plot of Messi's goals versus games
plt.scatter(df["Messi Games"], df["Messi Goals"])
plt.xlabel("Games")
plt.ylabel("Goals")
plt.title("Messi Goals versus Games")
plt.show()

# %%
# prediction of Ronaldo's goals based on his games and assists

# %%
# Define the features and target variable
X = df[["Ronaldo Games"]]
y = df["Ronaldo Goals"]

# Fit a linear regression model to the data
model = LinearRegression()
model.fit(X, y)

# Predict Ronaldo's goals for a new number of games
new_games = 30
new_data = pd.DataFrame({"Ronaldo Games": [new_games]})
new_goals = model.predict(new_data)

# Print the predicted number of goals
print("Predicted goals:", new_goals[0])
# Out:
# Predicted goals: 18.51855375832541

# %%
# Scatter plot of Ronaldo's goals versus games

# Create a scatter plot of Messi's goals versus games
plt.scatter(df["Ronaldo Games"], df["Ronaldo Goals"])
plt.xlabel("Games")
plt.ylabel("Goals")
plt.title("Ronaldo's Goals versus Games")
plt.show()

# %%
# Visualizing Messi's goals, assists, and games over time

# %%
# Select the relevant columns for Messi
messi_data = df[["Messi Goals", "Messi Assists", "Messi Games", "Year"]]

# Plot Messi's goals, assists, and games over time
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(messi_data["Year"], messi_data["Messi Goals"], label="Goals")
ax.plot(messi_data["Year"], messi_data["Messi Assists"], label="Assists")
ax.plot(messi_data["Year"], messi_data["Messi Games"], label="Games")
ax.set_xlabel("Year")
ax.set_ylabel("Count")
ax.set_title("Messi's Performance Over Time")
ax.legend()
plt.show()

# %%
# Visualizing Ronaldo's goals, assists, and games over time

# %%
# Select the relevant columns for Messi
ronaldo_data = df[["Ronaldo Goals", "Ronaldo Assists", "Ronaldo Games", "Year"]]

# Plot Messi's goals, assists, and games over time
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(ronaldo_data["Year"], ronaldo_data["Ronaldo Goals"], label="Goals")
ax.plot(ronaldo_data["Year"], ronaldo_data["Ronaldo Assists"], label="Assists")
ax.plot(ronaldo_data["Year"], ronaldo_data["Ronaldo Games"], label="Games")
ax.set_xlabel("Year")
ax.set_ylabel("Count")
ax.set_title("Ronaldo's Performance Over Time")
ax.legend()
plt.show()

# %%
# Plot Messi's and Ronaldo's goals against games

# %%
# Select the relevant columns for Messi and Ronaldo
messi_data = df[["Messi Goals", "Messi Assists", "Messi Games", "Year"]]
ronaldo_data = df[["Ronaldo Goals", "Ronaldo Assists", "Ronaldo Games", "Year"]]

fig, ax = plt.subplots(figsize=(10, 20))
ax.scatter(messi_data["Messi Games"], messi_data["Messi Goals"], label="Messi")
ax.scatter(ronaldo_data["Ronaldo Games"], ronaldo_data["Ronaldo Goals"], label="Ronaldo")
ax.set_xlabel("Games Played")
ax.set_ylabel("Goals Scored")
ax.set_title("Goals vs Games")
ax.legend()

# Add text labels for each point
for i in range(len(messi_data)):
    ax.text(messi_data.iloc[i]["Messi Games"] + 0.5, messi_data.iloc[i]["Messi Goals"], str(messi_data.iloc[i]["Year"]))
for i in range(len(ronaldo_data)):
    ax.text(ronaldo_data.iloc[i]["Ronaldo Games"] + 0.5, ronaldo_data.iloc[i]["Ronaldo Goals"], str(ronaldo_data.iloc[i]["Year"]))

plt.show()
